# %% [markdown]
# Testing jupyter

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# Pseudoco : scan intergers for largest
# Start
# scan the the numbers intergers
# 12,4,27,3,188,50,7
# Find the largest integers
# output the the interger
# End

# %%
nums = ["B",4,27,3,758,50,7]

def find_largest (nums):
    if not nums:
        return "No value to compare"
    largest = nums[0]

    for n in nums[1:]:
        if n > largest:
            largest = n
    
    return largest
print(find_largest(nums))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 13
#      10             largest = n
#      12     return largest
# ---> 13 print(find_largest(nums))
#
# Cell In[31], line 9, in find_largest(nums)
#       6 largest = nums[0]
#       8 for n in nums[1:]:
# ----> 9     if n > largest:
#      10         largest = n
#      12 return largest
#
# TypeError: '>' not supported between instances of 'int' and 'str'

# %% [markdown]
# Pseudoco : scan through intergers
# Start
# map through the list of integers to find all ods
# the intergers are [3,4,10,15,999,2]
# print the of intergers that are odd
# End

# %% [markdown]
# Assign1:
# start
#   Initualize counter to 0
#
#   for each number in the list :
#   if the number is an even interger:
#   Increase counter by 1
#   return counter
# end

# %%
num_list =[3,5,27,20,6,3.5,60]

def num_total(num_list):
    total = 0
    for x in num_list:
        if x % 2 == 0:
            total += x
    return total
print(num_total(num_list))
# Out:
# 86

# %% [markdown]
# Pseudoco : how to make a PB&J Sandwhich
# Start
# get your favorite loaf of bread
# grab your peanut butter, jelly and knife
# spread peanut butter on one side
# spread jelly on the other side
# put them together
# eat your sandwhich
# End
