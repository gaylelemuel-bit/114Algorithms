# %% [markdown]
# ## stacks
# A stack is an ordered collection of elements where items are added and removed from one end, commonly refferd to as the "top", The ordering principle is referred to as LIFO (Last In First Out)
#
# ##Quese
# A queue is an ordered collection of elements where items are added and removed from **opposite** ends, commonly reffered to as the "front" and "back" or "rear" of the queue. the ordering principle is reffered to as FIFO (First In First Out) or "first come first served"

# %%
stack= []
stack.append("A")
stack.append("B")
stack.append("C")
print(stack)

top = stack.pop()
print(top)
print(stack)
print(stack.pop())
print(stack)
stack.append("D")
print(stack)
print(stack.pop())
print(stack)
# Out:
# ['A', 'B', 'C']
# C
# ['A', 'B']
# B
# ['A']
# ['A', 'D']
# D
# ['A']

# %%
# challenge 2

stack = []
stack.append(2)
stack.append(4)
stack.append(6)
stack.append(8)
print(stack[3])

print(stack[len(stack)-1]) # this is the same as above
# Out:
# 8

# %%
stack = []
if len(stack) == 0:
    print("Stack is empty!")
else:
    print("thats crazy!, I didnt put nothing ")
# Out:
# Stack is empty!

# %%
#challenge
word= "HELLO"
stack= []
reversed_word = word[::-1]
print(reversed_word)
